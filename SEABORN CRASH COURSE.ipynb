# %% [markdown]
# # Data Visualization in Seaborn

# %% [markdown]
# **Visualizing Statistical relationships**

# %% [markdown]
# Statistical analysis is a process of understanding how variables in a dataset relate to each other and how those relationship depends on other variable. Visualization can be a core components of this process because when data are visualized properly, the human visual system can see the treds and patterns that indicate a relationship

# %% [markdown]
# **1. Numerical Data Plotting**

# %% [markdown]
# relplot()
#
# scatterplot()
#
# lineplot()

# %% [markdown]
# **2. Categorical Data Ploting**

# %% [markdown]
# catplot()
#
# boxplot()
#
# stripplot()
#
# swarmplot()
#
# etc…

# %% [markdown]
# **3. Visualizing Distribution of the Data**

# %% [markdown]
# distplot()
#
# kdeplot()
#
# jointplot()
#
# rugplot()

# %% [markdown]
# **4. Linear Regression and Relationship**

# %% [markdown]
# regplot()
#
# lmplot()

# %%
##Importing liabraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
##setting style
sns.set(style='darkgrid')

# %%
#loading dataset
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# **1. Numerical Data Plotting**

# %%
sns.relplot(x='total_bill',y='tip',data=tips)

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='time')

# %%
#changing color
sns.relplot(x='total_bill',y='tip',data=tips,hue='size',palette='ch:r=-0.2,l=0.75')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,size='size')

# %%
#changing sizes in seaborn
sns.relplot(x='total_bill',y='tip',data=tips,size='size',sizes=(15,200), palette='ch:r=-0.2,l=0.75')

# %%
#Lineplot
from numpy.random import randn
df = pd.DataFrame(dict(time=np.arange(500),value=randn(500).cumsum()))
df.head()
# Out:
#    time     value
# 0     0 -0.934431
# 1     1  0.005807
# 2     2 -1.734980
# 3     3 -1.836169
# 4     4 -1.795964

# %%
sns.relplot(x='time',y='value',data=df,kind='line')

# %%
#New DataFrame
df = pd.DataFrame(randn(500,2).cumsum(axis=0),columns=['time','value'])
df.shape
# Out:
# (500, 2)

# %%
sns.relplot(x='time',y='value',data=df,kind='line',sort=False)

# %%
sns.relplot(x='time',y='value',data=df,kind='line',sort=True)

# %%
#loading another Dataset
fmri = sns.load_dataset('fmri')

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x='timepoint',y='signal',kind='line',data=fmri)

# %%
sns.relplot(x='timepoint',y='signal',kind='line',data=fmri,ci=False)

# %%
sns.relplot(x='timepoint',y='signal',kind='line',data=fmri,ci='sd')

# %%
sns.relplot(x='timepoint',y='signal',kind='line',data=fmri,hue='event')

# %%
sns.relplot(x='timepoint',y='signal',kind='line',data=fmri,hue='region',style='event')

# %%
sns.relplot(x='timepoint',y='signal',kind='line',data=fmri,hue='region',style='event',marker=True,dashes=False)

# %%
#loading another dataset
dots = sns.load_dataset('dots').query("align =='dots'")

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(x='time',y='firing_rate',hue='coherence',data=dots,kind='line',style='choice')

# %%
palette= sns.cubehelix_palette(light = 0.5, n_colors=6)

# %%
sns.relplot(x='time',y='firing_rate',data=dots,kind='line',style='choice',hue='coherence',palette=palette)

# %%
#changing width of the line

# %%
sns.relplot(x='time',y='firing_rate',size='coherence',style='choice',kind='line',data=dots,sizes=(1,8),hue='coherence')

# %%
#ploting with the date

# %%
df = pd.DataFrame(dict(time=pd.date_range('2019-06-02',periods=500),value=randn(500).cumsum()))

# %%
df
# Out:
#           time     value
# 0   2019-06-02 -0.202887
# 1   2019-06-03  0.078972
# 2   2019-06-04  0.179684
# 3   2019-06-05 -0.987670
# 4   2019-06-06 -0.130113
# ..         ...       ...
# 495 2020-10-09 -1.924885
# 496 2020-10-10 -1.309292
# 497 2020-10-11  0.797335
# 498 2020-10-12 -0.073617
# 499 2020-10-13 -0.119392
#
# [500 rows x 2 columns]

# %%
g = sns.relplot(x='time',y='value',kind='line',data=df)

# %%
g = sns.relplot(x='time',y='value',kind='line',data=df)
g.fig.autofmt_xdate()

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',col='time')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',col='size')

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,hue='subject',col='region',row='event',height=3,kind='line',estimator=None)

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips)

# %%
sns.lineplot(x='total_bill',y='tip',data=tips)

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x='timepoint',y='signal',data=fmri,hue='event',style='event',marker=True,ci=68,err_style='bars')

# %%
sns.lineplot(x='timepoint',y='signal',data=fmri.query("region=='frontal'"),hue='event',units='subject',lw=1,estimator=None)

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.lineplot(x='time',y='firing_rate',hue='coherence',style='choice',data=dots)

# %%
sns.scatterplot(x='total_bill',y='tip',hue='sex',size='size',style='time',data=tips)

# %%
#loading dataset
iris= sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x='sepal_length',y='petal_length',data=iris)

# %%
sns.scatterplot(x=iris['sepal_length'],y=iris['petal_length'])

# %% [markdown]
# 2. Categorical Data Ploting
#
# catplot()
#
# boxplot()
#
# stripplot()
#
# swarmplot()
#
# etc…

# %% [markdown]
# # Data Visualization of categorical plot

# %%
#loading dataset

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#catplot
sns.catplot(x='day',y='total_bill',data=tips)

# %%
#catplot
sns.catplot(x='day',y='total_bill',data=tips,jitter=False)

# %%
#swarmplot
sns.catplot(x='day',y='total_bill',data=tips,hue='sex',kind='swarm')

# %%
sns.catplot(x='smoker',y='total_bill',data=tips,hue='sex',kind='swarm',order=['No','Yes'])

# %%
sns.catplot(x='day',y='total_bill',data=tips,hue='sex',kind='box')

# %%
sns.catplot(x='day',y='total_bill',data=tips,hue='sex',kind='box',dodge=False)

# %%
#loading dataset
diamond=sns.load_dataset('diamonds')

# %%
diamond.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x='color',y='price',kind='boxen',data=diamond.sort_values('color'))

# %%
sns.catplot(x='total_bill',y='day',hue='time',kind='violin',data=tips)

# %%
sns.catplot(x='total_bill',y='day',hue='time',kind='violin',data=tips,split=True,inner='stick')

# %%
#swarmplot and violin plot together
g=sns.catplot(x='day',y='total_bill',kind='violin',inner=None,data=tips)

# %%
sns.swarmplot(x='day',y='total_bill',color='k',size=3,data=tips,ax = g.ax)

# %%
#categorical plot vs Categorical plot
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x='sex',y='survived',hue='class',kind='bar',data=titanic)

# %%
#changing color gradint
sns.catplot(x='deck',kind='count',data=titanic,palette='ch:0.95')

# %%
#pointplot
sns.catplot(x='sex',y='survived',hue='class',kind='point',data=titanic)

# %% [markdown]
# 3. Visualizing Distribution of the Data
#
# distplot()
#
# kdeplot()
#
# jointplot()
#
# rugplot()

# %%
x = randn(100)

# %%
sns.distplot(x)

# %%
sns.distplot(x,kde=False,rug=True,bins=30)

# %%
sns.kdeplot(x,shade=True,cbar=True)

# %%
#Bivariate 
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
x =tips['total_bill']
y=tips['tip']

# %%
sns.jointplot(x=x,y=y,kind='hex')

# %%
sns.jointplot(x=x,y=y,kind='kde')

# %%
g = sns.jointplot(x,y,kind='kde',color='m')
g.plot_joint(plt.scatter,c='w',s=30,linewidth=1,marker='+')
g.ax_joint.collections[0].set_alpha(0)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot,nlevels=10)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:434: UserWarning: The following kwargs were not used by contour: 'nlevels'
#   cset = contour_func(xx, yy, z, n_levels, **kwargs)

# %% [markdown]
# 4. Linear Regression and Relationship
#
# regplot()
#
# lmplot()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='size',y='tip',data=tips,x_jitter=0.05)

# %%
sns.lmplot(x='size',y='tip',data=tips,x_estimator=np.mean)

# %%
#loading dataset
data = sns.load_dataset('anscombe')

# %%
data.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
sns.lmplot(x='x',y='y',data=data.query("dataset=='I'"))

# %%
sns.lmplot(x='x',y='y',data=data.query("dataset=='II'"))

# %%
sns.lmplot(x='x',y='y',data=data.query("dataset=='III'"))

# %%
#Removing outlier

# %%
sns.lmplot(x='x',y='y',data=data.query("dataset=='I'"),robust=True)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','x'],col='time',row='smoker')

# %% [markdown]
# #THANK YOU
